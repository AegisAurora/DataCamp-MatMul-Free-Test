# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# !pip install -U git+https://github.com/ridgerchu/matmulfreellm
# Out:
# Collecting git+https://github.com/ridgerchu/matmulfreellm
#   Cloning https://github.com/ridgerchu/matmulfreellm to /tmp/pip-req-build-ow3czn3y
#   Running command git clone --filter=blob:none --quiet https://github.com/ridgerchu/matmulfreellm /tmp/pip-req-build-ow3czn3y
#   Resolved https://github.com/ridgerchu/matmulfreellm to commit ec1c298ffa3db6436831f3e6d46f4e59d0b99194
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from mmfreelm==0.1) (2.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from mmfreelm==0.1) (4.41.2)
# Collecting einops (from mmfreelm==0.1)
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.1 MB/s eta 0:00:00
# Collecting ninja (from mmfreelm==0.1)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->mmfreelm==0.1) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers->mmfreelm==0.1) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers->mmfreelm==0.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->mmfreelm==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->mmfreelm==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->mmfreelm==0.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->mmfreelm==0.1) (2024.6.2)
# Building wheels for collected packages: mmfreelm
#   Building wheel for mmfreelm (setup.py) ... done
#   Created wheel for mmfreelm: filename=mmfreelm-0.1-py3-none-any.whl size=59337 sha256=7bdecb75939081476c51dc48bfcb2dbc67c525b0e77347993dd02d7690badb76
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4j78702e/wheels/1d/4d/52/e5d56167201a3959fff906933f33babdc4b4355f287c0c4689
# Successfully built mmfreelm
# Installing collected packages: ninja, einops, mmfreelm
# Successfully installed einops-0.8.0 mmfreelm-0.1 ninja-1.11.1.1

# %%
from mmfreelm.models import HGRNBitConfig

# %%
import torch
import time

# %%
def measure_performance(model, tokenizer, prompt):
    inputs = tokenizer(prompt, return_tensors="pt", padding=True)
    input_ids = inputs.input_ids.cuda()
    attention_mask = inputs.attention_mask.cuda()

    torch.cuda.reset_peak_memory_stats()


    start_time = time.time()
    with torch.no_grad():
        outputs = model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=128,
            pad_token_id=tokenizer.eos_token_id,
            repetition_penalty=1.1,
            no_repeat_ngram_size=2
        )
    end_time = time.time()


    peak_memory = torch.cuda.max_memory_allocated()  # Peak memory usage during the operation

    generation_time = end_time - start_time
    memory_consumption = peak_memory / (1024 ** 2)

    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generation_time, memory_consumption, generated_text

# %%
model_names = ["ridger/MMfreeLM-2.7B"]

# %%
prompts = ["What are the benefits of renewable energy?","Explain the theory of relativity.","Compose a poem about the changing seasons.","Explain the differences between supervised and unsupervised learning in machine learning.","What is one divided by zero"] #example prompt

# %%
def compare_models(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    model = AutoModelForCausalLM.from_pretrained(model_name).half().cuda()

    results = {}
    for prompt in prompts:
        time_taken, peak_memory_used, output = measure_performance(model, tokenizer, prompt)
        results[prompt] = {
            "time_taken": time_taken,
            "peak_memory_used": peak_memory_used,
            "output": output
        }

    del model
    torch.cuda.empty_cache()
    return results

# %%
all_results = {}
for model_name in model_names:
    all_results[model_name] = compare_models(model_name)


for model_name, model_results in all_results.items():
    print(f"Results for model: {model_name}\n{'=' * 50}")
    for prompt, result in model_results.items():
        print(f"Prompt: {prompt}")
        print(f"Time taken: {result['time_taken']:.2f} seconds")
        print(f"Peak memory used: {result['peak_memory_used']:.2f} MB")
        print(f"Output: {result['output']}")
        print("-" * 50)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/38.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Results for model: ridger/MMfreeLM-2.7B
# ==================================================
# Prompt: What are the benefits of renewable energy?
# Time taken: 57.31 seconds
# Peak memory used: 5499.81 MB
# Output: What are the benefits of renewable energy?
# The benefits for a community or an individual are that it provides the opportunity to reduce their carbon footprint in the short term and in a long term it reduces the amount of CO2 emissions. The benefits in this case are in terms of the reduction on the cost incurred on electricity bills, in addition in some cases you can get the tax credits in your country in order to make it more attractive in that way in particular in countries like Spain in which they have a very high level of solar energy in their energy mix in general in relation to other countries in Europe in fact the Spanish
# --------------------------------------------------
# Prompt: Explain the theory of relativity.
# Time taken: 34.99 seconds
# Peak memory used: 5499.75 MB
# Output: Explain the theory of relativity.
# 203: What is a particle? How are they made? What makes them move?
# 197: How do you know that you can't see an electron? Why can you not see it? It doesn' t exist!
# The first thing to understand about this is that we don' think in terms of particles and waves. We think of them as waves or particles, but that's not what they are. They're not particles at all. The reason for this confusion is because we've been taught for a long time that a wave is something
# --------------------------------------------------
# Prompt: Compose a poem about the changing seasons.
# Time taken: 34.69 seconds
# Peak memory used: 5499.81 MB
# Output: Compose a poem about the changing seasons.
#
# **_Suggestions for a Poem_**
#   * The poet should choose an interesting season in which to write this poem. This could be autumn, winter, spring, summer or fall. It could also be the time of year that you were born. You could choose to make your poem a celebration of this special time and the people who make it possible. The poem could have a happy ending or it could end on a sad note. In either case, this is your opportunity to tell us what it means to you!
#     * You may want to include some
# --------------------------------------------------
# Prompt: Explain the differences between supervised and unsupervised learning in machine learning.
# Time taken: 33.05 seconds
# Peak memory used: 5533.25 MB
# Output: Explain the differences between supervised and unsupervised learning in machine learning.
# 203: What are some of the problems that you have seen with supervision? How can it be solved?
# The problem is that we're trying to make a prediction for an unknown value in this case in the future in a new location in time in our data set in order to predict in that location on this day in future on that month in in on the next year in 10 years in ten years from now in one of these cases in which we don't know what the value will be in those locations in these
# --------------------------------------------------
# Prompt: What is one divided by zero
# Time taken: 36.16 seconds
# Peak memory used: 5499.62 MB
# Output: What is one divided by zero?
#
# A: It's the square root of 0.
# The square of a negative number is the same as that number multiplied by itself in base 10, so it has to be a positive number. The square is a number with no fractional part (the square has no decimal places).
# So for a non-negative integer $n$, we can write $2^n = \frac{2^{n+1}}{2}$ or $\frac{\sqrt{n!}}{4}$.
# If you want to find this value for an arbitrary positive integer, you
# --------------------------------------------------
